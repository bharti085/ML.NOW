# %% [markdown]
# <a href="https://colab.research.google.com/github/bharti085/ML.NOW/blob/main/EDA_titanic_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('/content/drive/MyDrive/Colab Notebooks/udemy files/titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.rename(columns={'Pclass':'ticket_class'},inplace=True)
df.head()
# Out:
#    PassengerId  Survived  ticket_class  ...            Ticket     Fare  Embarked
# 0            1         0             3  ...         A/5 21171   7.2500         S
# 1            2         1             1  ...          PC 17599  71.2833         C
# 2            3         1             3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1             1  ...            113803  53.1000         S
# 4            5         0             3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived  ...       Parch        Fare
# count   891.000000  891.000000  ...  891.000000  891.000000
# mean    446.000000    0.383838  ...    0.381594   32.204208
# std     257.353842    0.486592  ...    0.806057   49.693429
# min       1.000000    0.000000  ...    0.000000    0.000000
# 25%     223.500000    0.000000  ...    0.000000    7.910400
# 50%     446.000000    0.000000  ...    0.000000   14.454200
# 75%     668.500000    1.000000  ...    0.000000   31.000000
# max     891.000000    1.000000  ...    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
df.isnull()
# Out:
#      PassengerId  Survived  ticket_class   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False         False  False  ...   False  False   True     False
# 1          False     False         False  False  ...   False  False  False     False
# 2          False     False         False  False  ...   False  False   True     False
# 3          False     False         False  False  ...   False  False  False     False
# 4          False     False         False  False  ...   False  False   True     False
# ..           ...       ...           ...    ...  ...     ...    ...    ...       ...
# 886        False     False         False  False  ...   False  False   True     False
# 887        False     False         False  False  ...   False  False  False     False
# 888        False     False         False  False  ...   False  False   True     False
# 889        False     False         False  False  ...   False  False  False     False
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.hist(bins=20,figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c3b311810>,
# ...
#       dtype=object)

# %%
sns.heatmap(df.isnull(),cmap='viridis')

# %% [markdown]
# dealing with missing values

# %%
a= df['Embarked'].mode()[0]
a
# Out:
# 'S'

# %%
df['Embarked'] = df['Embarked'].fillna(a)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df.drop('Cabin',axis=1, inplace=True )

# %%
sns.boxplot(x='ticket_class', y='Age',data=df)

# %%
def impute_age(cols):
  Age=cols[0]
  ticket_class=cols[1]
  if pd.isnull(Age):
    if ticket_class==1:
      return 37
    elif ticket_class==2:
      return 29
    else:
      return 24
  else:
      return Age

# %%
df['Age']= df[['Age','ticket_class']].apply(impute_age, axis=1)

# %%
df.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# ticket_class    0
# Name            0
# Sex             0
# Age             0
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Embarked        0
# dtype: int64

# %%
sns.heatmap(df.isnull(),cmap='viridis')

# %%
df.head()
# Out:
#    PassengerId  Survived  ticket_class  ...            Ticket     Fare  Embarked
# 0            1         0             3  ...         A/5 21171   7.2500         S
# 1            2         1             1  ...          PC 17599  71.2833         C
# 2            3         1             3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1             1  ...            113803  53.1000         S
# 4            5         0             3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %% [markdown]
# dealing with categorical data

# %%
df.head()
# Out:
#    PassengerId  Survived  ticket_class  ...            Ticket     Fare  Embarked
# 0            1         0             3  ...         A/5 21171   7.2500         S
# 1            2         1             1  ...          PC 17599  71.2833         C
# 2            3         1             3  ...  STON/O2. 3101282   7.9250         S
# 3            4         1             1  ...            113803  53.1000         S
# 4            5         0             3  ...            373450   8.0500         S
#
# [5 rows x 11 columns]

# %%
sex= pd.get_dummies(df['Sex'],drop_first=True)
sex
# Out:
#      male
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
# ..    ...
# 886     1
# 887     0
# 888     0
# 889     1
# 890     1
#
# [891 rows x 1 columns]

# %%
embark=pd.get_dummies(df['Embarked'],drop_first=True)
embark
# Out:
#      Q  S
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 886  0  1
# 887  0  1
# 888  0  1
# 889  0  0
# 890  1  0
#
# [891 rows x 2 columns]

# %%
df.drop(['Sex','Embarked','Name','Ticket'],axis=1,inplace=True)

# %%
df= pd.concat([df,sex,embark], axis=1)

# %%
df.head()
# Out:
#    PassengerId  Survived  ticket_class   Age  SibSp  Parch     Fare  male  Q  S
# 0            1         0             3  22.0      1      0   7.2500     1  0  1
# 1            2         1             1  38.0      1      0  71.2833     0  0  0
# 2            3         1             3  26.0      0      0   7.9250     0  0  1
# 3            4         1             1  35.0      1      0  53.1000     0  0  1
# 4            5         0             3  35.0      0      0   8.0500     1  0  1

# %% [markdown]
# EDA

# %%
titanic_age_groups = pd.cut(df['Age'], bins=[0,15,25,40,55,70,80]).value_counts().sort_index()
titanic_age_groups
# Out:
# (0, 15]      83
# (15, 25]    354
# (25, 40]    304
# (40, 55]    110
# (55, 70]     35
# (70, 80]      5
# Name: Age, dtype: int64

# %%
.
